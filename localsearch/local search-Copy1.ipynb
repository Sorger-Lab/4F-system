# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.utils.np_utils import to_categorical
import keras
import tensorflow as tf
from tensorflow.keras import layers

# %%
train_data=np.load('E:\\code\\data\\MNIST_npy\\train_image.npy')/100
train_label=np.load('E:\\code\\data\\MNIST_npy\\train_label.npy')
test_data=np.load('E:\\code\\data\\MNIST_npy\\test_image.npy')/100
test_label=np.load('E:\\code\\data\\MNIST_npy\\test_label.npy')
train_label=to_categorical(train_label)
test_label=to_categorical(test_label)

# %%
input_shape=(28,28)
num_classes=10


inputs=tf.to_complex64(keras.Input(shape=input_shape))
input_fft=tf.signal.fft2d(inputs)
weights_fft = layer.get_weights()
conv_fft = keras.layers.Multiply(input_fft, weights_fft)
layer_output = tf.signal.ifft2d(conv_fft)

x=layers.Flatten()(layer_output)
outputs=layers.Dense(num_classes,activation="softmax")(x)


model=keras.Model(inputs,outputs)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_36180/2829779162.py in <module>
#       3
#       4
# ----> 5 inputs=tf.to_complex64(keras.Input(shape=input_shape))
#       6 input_fft=tf.signal.fft2d(inputs)
#       7 weights_fft = layer.get_weights()
#
# AttributeError: module 'tensorflow' has no attribute 'to_complex64'
