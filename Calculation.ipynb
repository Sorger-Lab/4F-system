# %%
import numpy as np
import imageio

# %%
pitch=7.6e-6
wavelength=633e-9
#focal=100e-3
focal=100e-3

wavelength/pitch*focal/pitch
# Out:
# 1095.9141274238227

# %%
pitch=10.8e-6
wavelength=633e-9
#focal=100e-3
focal=100e-3

wavelength/pitch*focal/pitch
# Out:
# 542.695473251029

# %%
466*1.6*1000/(27*340)
# Out:
# 81.22004357298475

# %%
angle=np.zeros((1620,1080))
